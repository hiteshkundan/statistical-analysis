# %% [markdown]
# **heart_failure_clinical_records**
#
# ---

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/heart_failure_clinical_records_dataset.csv")
print(df)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# **top 10 records of the data set**

# %%
df.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %% [markdown]
# **Performing descriptive statistics**

# %%
#calculate the basic descriptive statistics
print("MEAN:\n\n",df.mean())
print("\nMEDIAN:\n\n",df.median())
print("\nMODE:\n\n",df.mode().iloc[0])
print("\nSTANDARD DEVIATION:\n\n",df.std())
print("\nVARIANCE:\n\n",df.var())


#additional descriptive statistics
print("\nRANGE:\n\n",df.max()-df.min())
print("\nSKEWNESS:\n\n",df.skew())
print("\nKURTOSIS:\n\n",df.kurt())
# Out:
# MEAN:
#
#  age                             60.833893
# anaemia                          0.431438
# creatinine_phosphokinase       581.839465
# diabetes                         0.418060
# ejection_fraction               38.083612
# high_blood_pressure              0.351171
# platelets                   263358.029264
# serum_creatinine                 1.393880
# serum_sodium                   136.625418
# sex                              0.648829
# smoking                          0.321070
# time                           130.260870
# DEATH_EVENT                      0.321070
# dtype: float64
#
# MEDIAN:
#
#  age                             60.0
# anaemia                          0.0
# creatinine_phosphokinase       250.0
# diabetes                         0.0
# ejection_fraction               38.0
# high_blood_pressure              0.0
# platelets                   262000.0
# serum_creatinine                 1.1
# serum_sodium                   137.0
# ...

# %% [markdown]
# **Performing Inferential Statistics**

# %%
from scipy import stats#
#example data:age
platelets_values=df['platelets']
#population mean
population_mean = 0.05
#perform one sample test
t_stat, p_value = stats.ttest_1samp(age_values, population_mean)

print(f"T-static:{t_stat}")
print(f"p-vales:{p_value}")
# Out:
# T-static:88.36222238676538
# p-vales:8.308548309496484e-216

# %% [markdown]
# **Confidence Intervals**

# %%
import numpy as np
from scipy import stats
#Sample mean and standard error for platelets
sample_mean=np.mean(platelets_values)
standard_error=stats.sem(platelets_values)
# Compute 95% confidence interval for fetal_health
confidence_interval = stats.norm.interval(0.95, loc=sample_mean, scale=standard_error)
print(f"95% Confidence Interval for fetal_health: {confidence_interval}")
# Out:
# 95% Confidence Interval for fetal_health: (252272.14945782817, 274443.9090705999)

# %% [markdown]
# ** Regression Analysis**

# %%
import statsmodels.api as sm
# Define independent variable (add constant for intercept)
X = sm.add_constant(df['age'])
#define dependent variable
y = df['high_blood_pressure']
#fit linear regression model
model = sm.OLS(y, X).fit()
#print model summary
print(model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     high_blood_pressure   R-squared:                       0.009
# Model:                             OLS   Adj. R-squared:                  0.005
# Method:                  Least Squares   F-statistic:                     2.607
# Date:                 Sat, 07 Sep 2024   Prob (F-statistic):              0.107
# Time:                         04:57:32   Log-Likelihood:                -201.84
# No. Observations:                  299   AIC:                             407.7
# Df Residuals:                      297   BIC:                             415.1
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1230      0.144      0.855      0.393      -0.160       0.406
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot data and regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='high_blood_pressure', data=df, alpha=0.7)
sns.regplot(x='age', y='high_blood_pressure', data=df, scatter=False, color='red')

# Add labels and title
plt.xlabel('age')
plt.ylabel('high_blood_pressure')
plt.title('age vs high_blood_pressure with Regression Line')

# Show plot
plt.grid(True)
plt.show()

# %%
# Histogram of DEATH_EVENT by blood pressure
plt.figure(figsize=(8, 6))
sns.histplot(df['age'], bins=10)
plt.title('DEATH_EVENT by blood pressure')
plt.xlabel('DEATH_EVENT')
plt.ylabel('blood pressure')
plt.show()
